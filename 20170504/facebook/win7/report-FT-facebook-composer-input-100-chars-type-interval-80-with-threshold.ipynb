# %%
import pandas as pd
import numpy as np
import json 
import matplotlib.pyplot as plt
from os import environ


pd.options.display.float_format = '{:10,.2f}'.format
pd.set_option('display.width', 999)

key_index = ['actual_paint_frames',
            'expected_frames', 
            'frame_throughput',
            'long_frame']

with open('/Users/hasal/PycharmProjects/Hasal/test.json') as data_file:
    data = json.load(data_file)
    d = pd.DataFrame(data)
    df = pd.concat([pd.DataFrame(d[column]['time_list']).T for column in d], axis=1)
    df.columns = d.columns

    dft = df.loc[key_index, :]
    
dft
# Out:
#                     test_chrome_facebook_ft_type_composerbox_100_txt test_firefox_facebook_ft_type_composerbox_100_txt
# actual_paint_frames                                              106                                               106
# expected_frames                                                  884                                               884
# frame_throughput                                                0.12                                              0.12
# long_frame                                                    100.00                                            133.33

# %%
frame = pd.DataFrame([pd.Series(df[c]['time_sequence']).diff() \
                                                       .apply(lambda x: np.round(x/11.11)) \
                                                       .drop(0) \
                                                       .astype(int) for c in df]).T
frame.columns = df.columns
frame
# Out:
#      test_chrome_facebook_ft_type_composerbox_100_txt  test_firefox_facebook_ft_type_composerbox_100_txt
# 1                                                   1                                                  1
# 2                                                   9                                                  9
# 3                                                   9                                                  9
# 4                                                   9                                                  7
# 5                                                   9                                                  9
# 6                                                   9                                                 11
# 7                                                   9                                                  7
# 8                                                   9                                                  9
# 9                                                   9                                                  9
# 10                                                  9                                                  9
# 11                                                  9                                                  9
# 12                                                  9                                                  9
# 13                                                  9                                                 11
# 14                                                  9                                                  7
# 15                                                  9                                                  9
# 16                                                  9                                                 11
# 17                                                  9                                                  7
# 18                                                  9                                                 11
# 19                                                  9                                                  7
# 20                                                  9                                                  9
# 21                                                  9                                                  9
# 22                                                  9                                                 11
# 23                                                  9                                                  9
# 24                                                  9                                                  7
# 25                                                  9                                                  9
# 26                                                  9                                                  9
# 27                                                  9                                                 11
# 28                                                  9                                                  9
# 29                                                  9                                                  9
# 30                                                  9                                                  7
# ..                                                ...                                                ...
# 77                                                  9                                                 11
# 78                                                  9                                                  9
# 79                                                  9                                                  7
# 80                                                  9                                                  9
# 81                                                  9                                                 11
# 82                                                  9                                                  9
# 83                                                  9                                                  7
# 84                                                  9                                                 11
# 85                                                  9                                                  7
# 86                                                  9                                                 12
# 87                                                  2                                                  3
# 88                                                  3                                                  2
# 89                                                  1                                                  1
# 90                                                  2                                                  3
# 91                                                  1                                                  2
# 92                                                  5                                                  1
# 93                                                  3                                                  2
# 94                                                  1                                                  1
# 95                                                  2                                                  3
# 96                                                  7                                                  6
# 97                                                  9                                                  9
# 98                                                  9                                                  9
# 99                                                  9                                                  9
# 100                                                 9                                                  9
# 101                                                 9                                                  9
# 102                                                 9                                                 11
# 103                                                 9                                                  7
# 104                                                 9                                                  9
# 105                                                 9                                                 11
# 106                                                 9                                                  9
#
# [106 rows x 2 columns]

# %%
frame.quantile([0.01, 0.05, 0.95, 0.99], interpolation='nearest')
# Out:
#       test_chrome_facebook_ft_type_composerbox_100_txt  test_firefox_facebook_ft_type_composerbox_100_txt
# 0.01                                                 1                                                  1
# 0.05                                                 2                                                  2
# 0.95                                                 9                                                 11
# 0.99                                                 9                                                 11

# %%
frame.describe()
# Out:
#        test_chrome_facebook_ft_type_composerbox_100_txt  test_firefox_facebook_ft_type_composerbox_100_txt
# count                                            106.00                                             106.00
# mean                                               8.33                                               8.33
# std                                                2.06                                               2.49
# min                                                1.00                                               1.00
# 25%                                                9.00                                               7.00
# 50%                                                9.00                                               9.00
# 75%                                                9.00                                               9.00
# max                                                9.00                                              12.00

# %%
frame.hist( layout=(2,2), sharey=True, sharex=True, figsize=(20,10))
frame.plot(subplots=True, layout=(2,1), figsize=(20,20), ylim=(0,20))
plt.show()
