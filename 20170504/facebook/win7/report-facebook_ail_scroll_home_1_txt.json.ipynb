# %%
import glob
import json 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from os import environ
from IPython.display import display, HTML

key_index = ['avg_time',
            'max_time', 
            'med_time',
            'min_time',
            'std_dev']

#
# Read report filename from environment varilable 'file' 
#
filename = environ['file']
with open(filename) as data_file:
    data = json.load(data_file)
    d = pd.DataFrame(data)  

# drop empty 'time_list'
for c in d:
    if (d[c]['time_list'] == []) :
        d.drop(c, axis=1, inplace=True)
    
# Select columns and rows
d.loc[key_index, :]
# Out:
# /home/hasal/Hasal/.env-python/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
#          test_chrome_facebook_ail_scroll_home_1_txt  \
# avg_time                                      39.76
# max_time                                     112.36
# med_time                                    33.7079
# min_time                                    22.4719
# std_dev                                     17.4106
#
#          test_firefox_facebook_ail_scroll_home_1_txt
# avg_time                                     41.1569
# max_time                                     258.427
# med_time                                     33.7079
# min_time                                      11.236
# std_dev                                      41.5745

# %%
# Retrive 'run_time' from each run
runtime = pd.DataFrame([pd.DataFrame(d[c]['time_list'])['run_time'] for c in d]).T
runtime.columns = d.columns
runtime
# Out:
#     test_chrome_facebook_ail_scroll_home_1_txt  \
# 0                                    22.471910
# 1                                    22.471910
# 2                                    22.471910
# 3                                    22.471910
# 4                                    22.471910
# 5                                    33.707865
# 6                                    33.707865
# 7                                    33.707865
# 8                                    33.707865
# 9                                    33.707865
# 10                                   33.707865
# 11                                   33.707865
# 12                                   33.707865
# 13                                   33.707865
# 14                                   33.707865
# 15                                   33.707865
# 16                                   33.707865
# 17                                   34.090909
# 18                                   44.943820
# 19                                   44.943820
# 20                                   44.943820
# 21                                   44.943820
# 22                                   44.943820
# 23                                   44.943820
# 24                                   44.943820
# 25                                   44.943820
# 26                                   44.943820
# 27                                   45.454545
# 28                                   79.545455
# 29                                  112.359551
#
#     test_firefox_facebook_ail_scroll_home_1_txt
# 0                                     11.235955
# 1                                     11.235955
# 2                                     11.235955
# 3                                     11.235955
# 4                                     33.333333
# 5                                     33.333333
# 6                                     33.707865
# 7                                     33.707865
# 8                                     33.707865
# 9                                     33.707865
# 10                                    33.707865
# 11                                    33.707865
# 12                                    33.707865
# 13                                    33.707865
# 14                                    33.707865
# 15                                    33.707865
# 16                                    33.707865
# 17                                    33.707865
# 18                                    33.707865
# 19                                    33.707865
# 20                                    33.707865
# 21                                    44.444444
# 22                                    44.943820
# 23                                    44.943820
# 24                                    44.943820
# 25                                    44.943820
# 26                                    44.943820
# 27                                    44.943820
# 28                                    44.943820
# 29                                   258.426966

# %%
# Report percentile
runtime.quantile([0.01, 0.95, 0.99], interpolation='nearest')
# Out:
#       test_chrome_facebook_ail_scroll_home_1_txt  \
# 0.01                                   22.471910
# 0.95                                   79.545455
# 0.99                                  112.359551
#
#       test_firefox_facebook_ail_scroll_home_1_txt
# 0.01                                    11.235955
# 0.95                                    44.943820
# 0.99                                   258.426966

# %%
# Report summary
runtime.describe()
# Out:
#        test_chrome_facebook_ail_scroll_home_1_txt  \
# count                                   30.000000
# mean                                    39.759959
# std                                     17.708289
# min                                     22.471910
# 25%                                     33.707865
# 50%                                     33.707865
# 75%                                     44.943820
# max                                    112.359551
#
#        test_firefox_facebook_ail_scroll_home_1_txt
# count                                    30.000000
# mean                                     41.156887
# std                                      42.285265
# min                                      11.235955
# 25%                                      33.707865
# 50%                                      33.707865
# 75%                                      44.818976
# max                                     258.426966

# %%
# Plot input latency histogram
runtime.plot.hist(bins=20, 
                  histtype='bar', 
                  color=['green','orange', 'red', 'blue'], 
                  subplots=True, layout=(len(runtime.columns)/2,2), 
                  figsize=(20,10))
runtime.plot.box(subplots=True,
                 layout=(len(runtime.columns)/2,2),
                 sharey=True, sharex=True, figsize=(20, 10))
plt.show()
plt.show()
