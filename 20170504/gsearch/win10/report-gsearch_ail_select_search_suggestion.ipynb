# %%
import glob
import json 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from os import environ
from IPython.display import display, HTML

key_index = ['avg_time',
            'max_time', 
            'med_time',
            'min_time',
            'std_dev']

#
# Read report filename from environment varilable 'file' 
#
filename = environ['file']
with open(filename) as data_file:
    data = json.load(data_file)
    d = pd.DataFrame(data)  

# drop empty 'time_list'
for c in d:
    if (d[c]['time_list'] == []) :
        d.drop(c, axis=1, inplace=True)
    
# Select columns and rows
d.loc[key_index, :]
# Out:
#          test_firefox_gsearch_ail_select_search_suggestion
# avg_time                                           118.519
# max_time                                               200
# med_time                                           116.667
# min_time                                           66.6667
# std_dev                                            29.3038

# %%
# Retrive 'run_time' from each run
runtime = pd.DataFrame([pd.DataFrame(d[c]['time_list'])['run_time'] for c in d]).T
runtime.columns = d.columns
runtime
# Out:
#     test_firefox_gsearch_ail_select_search_suggestion
# 0                                          100.000000
# 1                                          133.333333
# 2                                          155.555556
# 3                                          133.333333
# 4                                          144.444444
# 5                                          100.000000
# 6                                          122.222222
# 7                                           77.777778
# 8                                          122.222222
# 9                                          100.000000
# 10                                          77.777778
# 11                                         133.333333
# 12                                         100.000000
# 13                                         133.333333
# 14                                         100.000000
# 15                                         111.111111
# 16                                         100.000000
# 17                                          88.888889
# 18                                         100.000000
# 19                                         188.888889
# 20                                         133.333333
# 21                                         100.000000
# 22                                         100.000000
# 23                                         122.222222
# 24                                         133.333333
# 25                                         111.111111
# 26                                          66.666667
# 27                                         122.222222
# 28                                         144.444444
# 29                                         200.000000

# %%
# Report percentile
runtime.quantile([0.01, 0.95, 0.99], interpolation='nearest')
# Out:
#       test_firefox_gsearch_ail_select_search_suggestion
# 0.01                                          66.666667
# 0.95                                         188.888889
# 0.99                                         200.000000

# %%
# Report summary
runtime.describe()
# Out:
#        test_firefox_gsearch_ail_select_search_suggestion
# count                                          30.000000
# mean                                          118.518519
# std                                            29.804719
# min                                            66.666667
# 25%                                           100.000000
# 50%                                           116.666667
# 75%                                           133.333333
# max                                           200.000000

# %%
# Plot input latency histogram
runtime.plot.hist(bins=20, 
                  histtype='bar', 
                  color=['green','orange', 'red', 'blue'], 
                  subplots=True, layout=(len(runtime.columns)/2,2), 
                  figsize=(20,10))
runtime.plot.box(subplots=True,
                 layout=(len(runtime.columns)/2,2),
                 sharey=True, sharex=True, figsize=(20, 10))
plt.show()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-fe03c559be9e> in <module>()
#       4                   color=['green','orange', 'red', 'blue'],
#       5                   subplots=True, layout=(len(runtime.columns)/2,2),
# ----> 6                   figsize=(20,10))
#       7 runtime.plot.box(subplots=True,
#       8                  layout=(len(runtime.columns)/2,2),
#
# /home/hasal/Hasal/.env-python/local/lib/python2.7/site-packages/pandas/tools/plotting.pyc in hist(self, by, bins, **kwds)
#    3870         axes : matplotlib.AxesSubplot or np.array of them
#    3871         """
# -> 3872         return self(kind='hist', by=by, bins=bins, **kwds)
#    3873
#    3874     def kde(self, **kwds):
#
# /home/hasal/Hasal/.env-python/local/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# /home/hasal/Hasal/.env-python/local/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2641                  yerr=yerr, xerr=xerr,
#    2642                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2643                  **kwds)
#    2644
#    2645
#
# /home/hasal/Hasal/.env-python/local/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2468         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2469
# -> 2470     plot_obj.generate()
#    2471     plot_obj.draw()
#    2472     return plot_obj.result
#
# /home/hasal/Hasal/.env-python/local/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#    1040         self._args_adjust()
#    1041         self._compute_plot_data()
# -> 1042         self._setup_subplots()
#    1043         self._make_plot()
#    1044         self._add_table()
#
# /home/hasal/Hasal/.env-python/local/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _setup_subplots(self)
#    1088                                   figsize=self.figsize, ax=self.ax,
#    1089                                   layout=self.layout,
# -> 1090                                   layout_type=self._layout_type)
#    1091         else:
#    1092             if self.ax is None:
#
# /home/hasal/Hasal/.env-python/local/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#    3404             fig.clear()
#    3405
# -> 3406     nrows, ncols = _get_layout(naxes, layout=layout, layout_type=layout_type)
#    3407     nplots = nrows * ncols
#    3408
#
# /home/hasal/Hasal/.env-python/local/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _get_layout(nplots, layout, layout_type)
#    3263         if nrows * ncols < nplots:
#    3264             raise ValueError('Layout of %sx%s must be larger than '
# -> 3265                              'required size %s' % (nrows, ncols, nplots))
#    3266
#    3267         return layout
#
# ValueError: Layout of 0x2 must be larger than required size 1
